# %% [markdown]
# # MD17: Ethanol (force field construction)
# This tutorial demonstrates how to use E3x to construct a machine-learned force field. For this example, we use the MD17 dataset for ethanol. The code is written to be easy to adapt to datasets that contain multiple molecules of different size.

# %%
filename = "/home/beemoqc2/Documents/e3x/docs/source/examples/test_data.npz"
model_train = "/home/beemoqc2/Documents/e3x/docs/source/examples/best_model_f32_l1_i5_b16_lion_400k.npz"
model_train_pickle = (
    "/home/beemoqc2/Documents/e3x/docs/source/examples/model_params_train.pkl"
)

# %%
import numpy as np
import pickle
import functools
import os
import urllib.request

import e3x
import flax.linen as nn
import jax
import jax.numpy as jnp
import numpy as np
import optax
from jax import device_put
# Disable future warnings.
import warnings

warnings.simplefilter(action="ignore", category=FutureWarning)

model = np.load(
    model_train,
    allow_pickle=True,
)
pesos_modelo = {}
for key in model.keys():
    array = model[key]
    pesos_modelo[key] = array

a = model["model"]
a = a.item()

with open(model_train_pickle, "wb") as file:
    pickle.dump(a, file)

# %%
# Atomic energies: V + 16 * Si
rm_atom_energ = True
atom_energ = -3507661.3898417074  # kcal/mol

# --- Model hyperparameters ---
features = 32
max_degree = 1
num_iterations = 5
num_basis_functions = 16
cutoff = 10.0
max_atomic_number = 26
# -----------------------------

# --------- Optimizador ------
str_optim = "adam"
# ----------------------------

tail_str = (
    f"f{features}_l{max_degree}_i{num_iterations}_b{num_basis_functions}_{str_optim}"
)

# ---- Training hyperparameters ----
num_train = 4000
num_valid = 1000
num_epochs = 5000
learning_rate = 0.001
forces_weight = 0.9
batch_size = 100
# ----------------------------------

# %%
def prepare_datasets(key, num_train, num_valid):
    # Load the dataset.
    dataset = np.load(filename)

    if rm_atom_energ:
        dataset["E"][:] -= atom_energ
        print("--> Atomic energies removed")

    # Make sure that the dataset contains enough entries.
    num_data = len(dataset["E"])
    num_draw = num_train + num_valid
    if num_draw > num_data:
        raise RuntimeError(
            f"datasets only contains {num_data} points, requested num_train={num_train}, num_valid={num_valid}"
        )

    # Randomly draw train and validation sets from dataset.
    choice = np.asarray(
        jax.random.choice(key, num_data, shape=(num_draw,), replace=False)
    )
    train_choice = choice[:num_train]
    valid_choice = choice[num_train:]

    # Determine mean energy of the training set.
    mean_energy = np.mean(dataset["E"][train_choice])  # ~ -97000
    print(f"mean_energy: {mean_energy}")

    # Collect and return train and validation sets.
    train_data = dict(
        energy=jnp.asarray(dataset["E"][train_choice, 0] - mean_energy),
        forces=jnp.asarray(dataset["F"][train_choice]),
        atomic_numbers=jnp.asarray(dataset["z"]),
        # atomic_numbers=jnp.asarray(z_hack),
        positions=jnp.asarray(dataset["R"][train_choice]),
    )
    valid_data = dict(
        energy=jnp.asarray(dataset["E"][valid_choice, 0] - mean_energy),
        forces=jnp.asarray(dataset["F"][valid_choice]),
        atomic_numbers=jnp.asarray(dataset["z"]),
        # atomic_numbers=jnp.asarray(z_hack),
        positions=jnp.asarray(dataset["R"][valid_choice]),
    )
    return train_data, valid_data, mean_energy


class MessagePassingModel(nn.Module):
    features: int = 32
    max_degree: int = 2
    num_iterations: int = 3
    num_basis_functions: int = 8
    cutoff: float = 5.0
    max_atomic_number: int = 118  # This is overkill for most applications.

    def energy(
        self, atomic_numbers, positions, dst_idx, src_idx, batch_segments, batch_size
    ):
        # 1. Calculate displacement vectors.
        positions_dst = e3x.ops.gather_dst(positions, dst_idx=dst_idx)
        positions_src = e3x.ops.gather_src(positions, src_idx=src_idx)
        displacements = positions_src - positions_dst  # Shape (num_pairs, 3).

        # 2. Expand displacement vectors in basis functions.
        basis = e3x.nn.basis(  # Shape (num_pairs, 1, (max_degree+1)**2, num_basis_functions).
            displacements,
            num=self.num_basis_functions,
            max_degree=self.max_degree,
            radial_fn=e3x.nn.reciprocal_bernstein,
            cutoff_fn=functools.partial(e3x.nn.smooth_cutoff, cutoff=self.cutoff),
        )

        # 3. Embed atomic numbers in feature space, x has shape (num_atoms, 1, 1, features).
        x = e3x.nn.Embed(
            num_embeddings=self.max_atomic_number + 1, features=self.features
        )(atomic_numbers)

        # 4. Perform iterations (message-passing + atom-wise refinement).
        for i in range(self.num_iterations):
            # Message-pass.
            if i == self.num_iterations - 1:  # Final iteration.
                # Since we will only use scalar features after the final message-pass, we do not want to produce non-scalar
                # features for efficiency reasons.
                y = e3x.nn.MessagePass(max_degree=0, include_pseudotensors=False)(
                    x, basis, dst_idx=dst_idx, src_idx=src_idx
                )
                # After the final message pass, we can safely throw away all non-scalar features.
                x = e3x.nn.change_max_degree_or_type(
                    x, max_degree=0, include_pseudotensors=False
                )
            else:
                # In intermediate iterations, the message-pass should consider all possible coupling paths.
                y = e3x.nn.MessagePass()(x, basis, dst_idx=dst_idx, src_idx=src_idx)
            y = e3x.nn.add(x, y)

            # Atom-wise refinement MLP.
            y = e3x.nn.Dense(self.features)(y)
            y = e3x.nn.silu(y)
            y = e3x.nn.Dense(self.features, kernel_init=jax.nn.initializers.zeros)(y)

            # Residual connection.
            x = e3x.nn.add(x, y)

        # 5. Predict atomic energies with an ordinary dense layer.
        element_bias = self.param(
            "element_bias",
            lambda rng, shape: jnp.zeros(shape),
            (self.max_atomic_number + 1),
        )
        atomic_energies = nn.Dense(
            1, use_bias=False, kernel_init=jax.nn.initializers.zeros
        )(
            x
        )  # (..., Natoms, 1, 1, 1)
        atomic_energies = jnp.squeeze(
            atomic_energies, axis=(-1, -2, -3)
        )  # Squeeze last 3 dimensions.
        atomic_energies += element_bias[atomic_numbers]

        # 6. Sum atomic energies to obtain the total energy.
        energy = jax.ops.segment_sum(
            atomic_energies, segment_ids=batch_segments, num_segments=batch_size
        )

        # To be able to efficiently compute forces, our model should return a single output (instead of one for each
        # molecule in the batch). Fortunately, since all atomic contributions only influence the energy in their own
        # batch segment, we can simply sum the energy of all molecules in the batch to obtain a single proxy output
        # to differentiate.
        return (
            -jnp.sum(energy),
            energy,
        )  # Forces are the negative gradient, hence the minus sign.

    @nn.compact
    def __call__(
        self,
        atomic_numbers,
        positions,
        dst_idx,
        src_idx,
        batch_segments=None,
        batch_size=None,
    ):
        if batch_segments is None:
            batch_segments = jnp.zeros_like(atomic_numbers)
            batch_size = 1

        # Since we want to also predict forces, i.e. the gradient of the energy w.r.t. positions (argument 1), we use
        # jax.value_and_grad to create a function for predicting both energy and forces for us.
        energy_and_forces = jax.value_and_grad(self.energy, argnums=1, has_aux=True)
        (_, energy), forces = energy_and_forces(
            atomic_numbers, positions, dst_idx, src_idx, batch_segments, batch_size
        )

        return energy, forces


def prepare_batches(key, data, batch_size):
    # Determine the number of training steps per epoch.
    data_size = len(data["energy"])
    steps_per_epoch = data_size // batch_size

    # Draw random permutations for fetching batches from the train data.
    perms = jax.random.permutation(key, data_size)
    perms = perms[
        : steps_per_epoch * batch_size
    ]  # Skip the last batch (if incomplete).
    perms = perms.reshape((steps_per_epoch, batch_size))

    # Prepare entries that are identical for each batch.
    num_atoms = len(data["atomic_numbers"])
    batch_segments = jnp.repeat(jnp.arange(batch_size), num_atoms)
    atomic_numbers = jnp.tile(data["atomic_numbers"], batch_size)
    offsets = jnp.arange(batch_size) * num_atoms
    dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(num_atoms)
    dst_idx = (dst_idx + offsets[:, None]).reshape(-1)
    src_idx = (src_idx + offsets[:, None]).reshape(-1)

    # Assemble and return batches.
    return [
        dict(
            energy=data["energy"][perm],
            forces=data["forces"][perm].reshape(-1, 3),
            atomic_numbers=atomic_numbers,
            positions=data["positions"][perm].reshape(-1, 3),
            dst_idx=dst_idx,
            src_idx=src_idx,
            batch_segments=batch_segments,
        )
        for perm in perms
    ]


def mean_squared_loss(
    energy_prediction, energy_target, forces_prediction, forces_target, forces_weight
):
    energy_loss = jnp.mean(optax.l2_loss(energy_prediction, energy_target))
    forces_loss = jnp.mean(optax.l2_loss(forces_prediction, forces_target))
    return energy_loss + forces_weight * forces_loss


def mean_absolute_error(prediction, target):
    return jnp.mean(jnp.abs(prediction - target))


@functools.partial(
    jax.jit, static_argnames=("model_apply", "optimizer_update", "batch_size")
)
def train_step(
    model_apply, optimizer_update, batch, batch_size, forces_weight, opt_state, params
):
    def loss_fn(params):
        energy, forces = model_apply(
            params,
            atomic_numbers=batch["atomic_numbers"],
            positions=batch["positions"],
            dst_idx=batch["dst_idx"],
            src_idx=batch["src_idx"],
            batch_segments=batch["batch_segments"],
            batch_size=batch_size,
        )
        loss = mean_squared_loss(
            energy_prediction=energy,
            energy_target=batch["energy"],
            forces_prediction=forces,
            forces_target=batch["forces"],
            forces_weight=forces_weight,
        )
        return loss, (energy, forces)

    (loss, (energy, forces)), grad = jax.value_and_grad(loss_fn, has_aux=True)(params)

    updates, opt_state = optimizer_update(grad, opt_state, params)

    params = optax.apply_updates(params, updates)

    energy_mae = mean_absolute_error(energy, batch["energy"])
    forces_mae = mean_absolute_error(forces, batch["forces"])

    return params, opt_state, loss, energy_mae, forces_mae


@functools.partial(jax.jit, static_argnames=("model_apply", "batch_size"))
def eval_step(model_apply, batch, batch_size, forces_weight, params):
    energy, forces = model_apply(
        params,
        atomic_numbers=batch["atomic_numbers"],
        positions=batch["positions"],
        dst_idx=batch["dst_idx"],
        src_idx=batch["src_idx"],
        batch_segments=batch["batch_segments"],
        batch_size=batch_size,
    )
    loss = mean_squared_loss(
        energy_prediction=energy,
        energy_target=batch["energy"],
        forces_prediction=forces,
        forces_target=batch["forces"],
        forces_weight=forces_weight,
    )
    energy_mae = mean_absolute_error(energy, batch["energy"])
    forces_mae = mean_absolute_error(forces, batch["forces"])
    return loss, energy_mae, forces_mae


def train_model(
    key,
    model,
    train_data,
    valid_data,
    num_epochs,
    learning_rate,
    forces_weight,
    batch_size,
):
    # Initialize model parameters and optimizer state.
    print("Initialize model parameters and optimizer state.")
    key, init_key = jax.random.split(key)

    if str_optim == "adam":
        optimizer = optax.adam(learning_rate)
    elif str_optim == "adabelief":
        optimizer = optax.adabelief(learning_rate)
    elif str_optim == "lamb":
        optimizer = optax.lamb(learning_rate)
    elif str_optim == "lion":
        optimizer = optax.lion(0.1 * learning_rate, weight_decay=0.005)

    dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(
        len(train_data["atomic_numbers"])
    )
    with open(
        model_train_pickle,
        "rb",
    ) as file:
        loaded_params = pickle.load(file)

    params = loaded_params

    opt_state = optimizer.init(params)

    # Batches for the validation set need to be prepared only once.
    print("Batches for the validation set need to be prepared only once")
    key, shuffle_key = jax.random.split(key)
    valid_batches = prepare_batches(shuffle_key, valid_data, batch_size)

    # Train for 'num_epochs' epochs.
    print("Starts training loop...")
    for epoch in range(1, num_epochs + 1):
        # Prepare batches.
        key, shuffle_key = jax.random.split(key)
        train_batches = prepare_batches(shuffle_key, train_data, batch_size)

        # Loop over train batches.
        train_loss = 0.0
        train_energy_mae = 0.0
        train_forces_mae = 0.0
        for i, batch in enumerate(train_batches):
            params, opt_state, loss, energy_mae, forces_mae = train_step(
                model_apply=model.apply,
                optimizer_update=optimizer.update,
                batch=batch,
                batch_size=batch_size,
                forces_weight=forces_weight,
                opt_state=opt_state,
                params=params,
            )

            train_loss += (loss - train_loss) / (i + 1)
            train_energy_mae += (energy_mae - train_energy_mae) / (i + 1)
            train_forces_mae += (forces_mae - train_forces_mae) / (i + 1)

        # Evaluate on validation set.
        valid_loss = 0.0
        valid_energy_mae = 0.0
        valid_forces_mae = 0.0

        for i, batch in enumerate(valid_batches):
            loss, energy_mae, forces_mae = eval_step(
                model_apply=model.apply,
                batch=batch,
                batch_size=batch_size,
                forces_weight=forces_weight,
                params=params,
            )

            valid_loss += (loss - valid_loss) / (i + 1)
            valid_energy_mae += (energy_mae - valid_energy_mae) / (i + 1)
            valid_forces_mae += (forces_mae - valid_forces_mae) / (i + 1)

        # Print progress.
        print(f"epoch: {epoch: 3d}                    train:   valid:")
        print(f"    loss [a.u.]             {train_loss : 8.3f} {valid_loss : 8.3f}")
        print(
            f"    energy mae [kcal/mol]   {train_energy_mae: 8.3f} {valid_energy_mae: 8.3f}"
        )
        print(
            f"    forces mae [kcal/mol/A] {train_forces_mae: 8.3f} {valid_forces_mae: 8.3f}"
        )

        # Best model
        if epoch == 1:
            valid_loss_best = 1e10
            valid_energy_mae_best = 1e10
            valid_forces_mae_best = 1e10

        if jnp.isnan(train_forces_mae) or jnp.isnan(valid_forces_mae):
            print("BREAK: Nan appeared")
            print(f"--------- BEST MODEL --------")
            print(f"    loss [a.u.]             {valid_loss_best : 8.3f}")
            print(f"    energy mae [kcal/mol]   {valid_energy_mae_best: 8.3f}")
            print(f"    forces mae [kcal/mol/A] {valid_forces_mae_best: 8.3f}")
            break

        if valid_forces_mae < valid_forces_mae_best:
            print("Updating best model...")
            params_best = params.copy()
            valid_loss_best = valid_loss
            valid_energy_mae_best = valid_energy_mae
            valid_forces_mae_best = valid_forces_mae
            # Store best model
            params_best = device_put(params_best)
            params_2save = {
                "errors": [valid_loss_best, valid_energy_mae, valid_forces_mae],
                "model": params_best,
            }
            jnp.savez(f"best_model_{tail_str}_tmp.npz", **params_2save)

        if os.path.exists("early_stop"):
            print("BREAK: early_stop")
            print(f"--------- BEST MODEL --------")
            print(f"    loss [a.u.]             {valid_loss_best : 8.3f}")
            print(f"    energy mae [kcal/mol]   {valid_energy_mae_best: 8.3f}")
            print(f"    forces mae [kcal/mol/A] {valid_forces_mae_best: 8.3f}")
            break

    # Return final model parameters.
    print(f"--------- BEST MODEL --------")
    print(f"    loss [a.u.]             {valid_loss : 8.3f}")
    print(f"    energy mae [kcal/mol]   {valid_energy_mae: 8.3f}")
    print(f"    forces mae [kcal/mol/A] {valid_forces_mae: 8.3f}")
    return params_best


# Create PRNGKeys.
data_key, train_key = jax.random.split(jax.random.PRNGKey(0), 2)

# Draw training and validation sets.
train_data, valid_data, _ = prepare_datasets(
    data_key, num_train=num_train, num_valid=num_valid
)

# Create and train model.
print("Creating MP model...")
message_passing_model = MessagePassingModel(
    features=features,
    max_degree=max_degree,
    num_iterations=num_iterations,
    num_basis_functions=num_basis_functions,
    cutoff=cutoff,
    max_atomic_number=max_atomic_number,
)
print("Creating MP model [DONE]")

print("Start training model...")
params = train_model(
    key=train_key,
    model=message_passing_model,
    train_data=train_data,
    valid_data=valid_data,
    num_epochs=num_epochs,
    learning_rate=learning_rate,
    forces_weight=forces_weight,
    batch_size=batch_size,
)
print("Start training model [DONE]")
# print(params)
# Out:
# --> Atomic energies removed
# mean_energy: -3513804.036949912
# Creating MP model...
# Creating MP model [DONE]
# Start training model...
# Initialize model parameters and optimizer state.
# Batches for the validation set need to be prepared only once
# Starts training loop...
# epoch:   1                    train:   valid:
#     loss [a.u.]                0.829    0.380
#     energy mae [kcal/mol]      0.430    0.246
#     forces mae [kcal/mol/A]    0.874    0.636
# Updating best model...
# epoch:   2                    train:   valid:
#     loss [a.u.]                0.317    0.287
#     energy mae [kcal/mol]      0.211    0.206
#     forces mae [kcal/mol/A]    0.580    0.543
# Updating best model...
# epoch:   3                    train:   valid:
#     loss [a.u.]                0.258    0.252
#     energy mae [kcal/mol]      0.182    0.188
#     forces mae [kcal/mol/A]    0.523    0.509
# Updating best model...
# epoch:   4                    train:   valid:
#     loss [a.u.]                0.229    0.227
#     energy mae [kcal/mol]      0.166    0.167
#     forces mae [kcal/mol/A]    0.492    0.485
# Updating best model...
# epoch:   5                    train:   valid:
#     loss [a.u.]                0.211    0.212
#     energy mae [kcal/mol]      0.156    0.154
#     forces mae [kcal/mol/A]    0.471    0.468
# Updating best model...
# epoch:   6                    train:   valid:
#     loss [a.u.]                0.196    0.203
#     energy mae [kcal/mol]      0.142    0.145
#     forces mae [kcal/mol/A]    0.454    0.456
# Updating best model...
# epoch:   7                    train:   valid:
#     loss [a.u.]                0.192    0.193
#     energy mae [kcal/mol]      0.160    0.146
#     forces mae [kcal/mol/A]    0.444    0.443
# Updating best model...
# epoch:   8                    train:   valid:
#     loss [a.u.]                0.179    0.186
#     energy mae [kcal/mol]      0.140    0.138
#     forces mae [kcal/mol/A]    0.432    0.436
# Updating best model...
# epoch:   9                    train:   valid:
#     loss [a.u.]                0.172    0.179
#     energy mae [kcal/mol]      0.132    0.132
#     forces mae [kcal/mol/A]    0.424    0.425
# Updating best model...
# epoch:  10                    train:   valid:
#     loss [a.u.]                0.166    0.176
#     energy mae [kcal/mol]      0.127    0.139
#     forces mae [kcal/mol/A]    0.415    0.420
# Updating best model...
# epoch:  11                    train:   valid:
#     loss [a.u.]                0.165    0.176
#     energy mae [kcal/mol]      0.142    0.151
#     forces mae [kcal/mol/A]    0.410    0.417
# Updating best model...
# epoch:  12                    train:   valid:
#     loss [a.u.]                0.157    0.166
#     energy mae [kcal/mol]      0.125    0.123
#     forces mae [kcal/mol/A]    0.403    0.408
# Updating best model...
# epoch:  13                    train:   valid:
#     loss [a.u.]                0.155    0.168
#     energy mae [kcal/mol]      0.127    0.142
#     forces mae [kcal/mol/A]    0.397    0.408
# Updating best model...
# epoch:  14                    train:   valid:
#     loss [a.u.]                0.151    0.162
#     energy mae [kcal/mol]      0.121    0.131
#     forces mae [kcal/mol/A]    0.394    0.399
# Updating best model...
# epoch:  15                    train:   valid:
#     loss [a.u.]                0.150    0.164
#     energy mae [kcal/mol]      0.133    0.156
#     forces mae [kcal/mol/A]    0.389    0.399
# Updating best model...
# epoch:  16                    train:   valid:
#     loss [a.u.]                0.145    0.155
#     energy mae [kcal/mol]      0.118    0.114
#     forces mae [kcal/mol/A]    0.386    0.393
# Updating best model...
# epoch:  17                    train:   valid:
#     loss [a.u.]                0.142    0.157
#     energy mae [kcal/mol]      0.115    0.136
#     forces mae [kcal/mol/A]    0.382    0.391
# Updating best model...
# epoch:  18                    train:   valid:
#     loss [a.u.]                0.139    0.151
#     energy mae [kcal/mol]      0.110    0.115
#     forces mae [kcal/mol/A]    0.378    0.385
# Updating best model...
# epoch:  19                    train:   valid:
#     loss [a.u.]                0.136    0.151
#     energy mae [kcal/mol]      0.108    0.124
#     forces mae [kcal/mol/A]    0.374    0.384
# Updating best model...
# epoch:  20                    train:   valid:
#     loss [a.u.]                0.136    0.153
#     energy mae [kcal/mol]      0.120    0.143
#     forces mae [kcal/mol/A]    0.372    0.384
# epoch:  21                    train:   valid:
#     loss [a.u.]                0.134    0.148
#     energy mae [kcal/mol]      0.112    0.118
#     forces mae [kcal/mol/A]    0.370    0.379
# Updating best model...
# epoch:  22                    train:   valid:
#     loss [a.u.]                0.133    0.147
#     energy mae [kcal/mol]      0.111    0.123
#     forces mae [kcal/mol/A]    0.368    0.376
# Updating best model...
# epoch:  23                    train:   valid:
#     loss [a.u.]                0.130    0.152
#     energy mae [kcal/mol]      0.113    0.165
#     forces mae [kcal/mol/A]    0.364    0.376
# epoch:  24                    train:   valid:
#     loss [a.u.]                0.130    0.142
#     energy mae [kcal/mol]      0.116    0.107
#     forces mae [kcal/mol/A]    0.363    0.374
# Updating best model...
# epoch:  25                    train:   valid:
#     loss [a.u.]                0.126    0.142
#     energy mae [kcal/mol]      0.099    0.110
#     forces mae [kcal/mol/A]    0.359    0.372
# Updating best model...
# epoch:  26                    train:   valid:
#     loss [a.u.]                0.126    0.141
#     energy mae [kcal/mol]      0.107    0.104
#     forces mae [kcal/mol/A]    0.358    0.372
# epoch:  27                    train:   valid:
#     loss [a.u.]                0.126    0.140
#     energy mae [kcal/mol]      0.110    0.105
#     forces mae [kcal/mol/A]    0.358    0.369
# Updating best model...
# epoch:  28                    train:   valid:
#     loss [a.u.]                0.123    0.137
#     energy mae [kcal/mol]      0.100    0.108
#     forces mae [kcal/mol/A]    0.354    0.364
# Updating best model...
# epoch:  29                    train:   valid:
#     loss [a.u.]                0.123    0.136
#     energy mae [kcal/mol]      0.108    0.104
#     forces mae [kcal/mol/A]    0.352    0.367
# epoch:  30                    train:   valid:
#     loss [a.u.]                0.121    0.134
#     energy mae [kcal/mol]      0.104    0.102
#     forces mae [kcal/mol/A]    0.352    0.360
# Updating best model...
# epoch:  31                    train:   valid:
#     loss [a.u.]                0.119    0.134
#     energy mae [kcal/mol]      0.099    0.104
#     forces mae [kcal/mol/A]    0.348    0.360
# epoch:  32                    train:   valid:
#     loss [a.u.]                0.118    0.134
#     energy mae [kcal/mol]      0.102    0.109
#     forces mae [kcal/mol/A]    0.346    0.358
# Updating best model...
# epoch:  33                    train:   valid:
#     loss [a.u.]                0.118    0.134
#     energy mae [kcal/mol]      0.108    0.120
#     forces mae [kcal/mol/A]    0.344    0.357
# Updating best model...
# epoch:  34                    train:   valid:
#     loss [a.u.]                0.117    0.137
#     energy mae [kcal/mol]      0.103    0.108
#     forces mae [kcal/mol/A]    0.343    0.364
# epoch:  35                    train:   valid:
#     loss [a.u.]                0.116    0.132
#     energy mae [kcal/mol]      0.097    0.104
#     forces mae [kcal/mol/A]    0.344    0.357
# epoch:  36                    train:   valid:
#     loss [a.u.]                0.115    0.134
#     energy mae [kcal/mol]      0.095    0.111
#     forces mae [kcal/mol/A]    0.342    0.359
# epoch:  37                    train:   valid:
#     loss [a.u.]                0.114    0.131
#     energy mae [kcal/mol]      0.096    0.114
#     forces mae [kcal/mol/A]    0.340    0.355
# Updating best model...
# epoch:  38                    train:   valid:
#     loss [a.u.]                0.116    0.129
#     energy mae [kcal/mol]      0.111    0.101
#     forces mae [kcal/mol/A]    0.341    0.352
# Updating best model...
# epoch:  39                    train:   valid:
#     loss [a.u.]                0.112    0.130
#     energy mae [kcal/mol]      0.092    0.116
#     forces mae [kcal/mol/A]    0.337    0.350
# Updating best model...
# epoch:  40                    train:   valid:
#     loss [a.u.]                0.111    0.130
#     energy mae [kcal/mol]      0.096    0.112
#     forces mae [kcal/mol/A]    0.335    0.352
# epoch:  41                    train:   valid:
#     loss [a.u.]                0.110    0.131
#     energy mae [kcal/mol]      0.095    0.110
#     forces mae [kcal/mol/A]    0.334    0.354
# epoch:  42                    train:   valid:
#     loss [a.u.]                0.110    0.128
#     energy mae [kcal/mol]      0.097    0.106
#     forces mae [kcal/mol/A]    0.333    0.348
# Updating best model...
# epoch:  43                    train:   valid:
#     loss [a.u.]                0.108    0.127
#     energy mae [kcal/mol]      0.088    0.102
#     forces mae [kcal/mol/A]    0.331    0.348
# epoch:  44                    train:   valid:
#     loss [a.u.]                0.108    0.128
#     energy mae [kcal/mol]      0.096    0.126
#     forces mae [kcal/mol/A]    0.330    0.348
# Updating best model...
# epoch:  45                    train:   valid:
#     loss [a.u.]                0.107    0.126
#     energy mae [kcal/mol]      0.094    0.102
#     forces mae [kcal/mol/A]    0.330    0.347
# Updating best model...
# epoch:  46                    train:   valid:
#     loss [a.u.]                0.106    0.127
#     energy mae [kcal/mol]      0.089    0.100
#     forces mae [kcal/mol/A]    0.328    0.349
# epoch:  47                    train:   valid:
#     loss [a.u.]                0.108    0.124
#     energy mae [kcal/mol]      0.096    0.099
#     forces mae [kcal/mol/A]    0.329    0.343
# Updating best model...
# epoch:  48                    train:   valid:
#     loss [a.u.]                0.106    0.125
#     energy mae [kcal/mol]      0.096    0.106
#     forces mae [kcal/mol/A]    0.327    0.344
# epoch:  49                    train:   valid:
#     loss [a.u.]                0.107    0.126
#     energy mae [kcal/mol]      0.102    0.102
#     forces mae [kcal/mol/A]    0.328    0.346
# epoch:  50                    train:   valid:
#     loss [a.u.]                0.105    0.121
#     energy mae [kcal/mol]      0.094    0.096
#     forces mae [kcal/mol/A]    0.326    0.340
# Updating best model...
# epoch:  51                    train:   valid:
#     loss [a.u.]                0.103    0.124
#     energy mae [kcal/mol]      0.087    0.107
#     forces mae [kcal/mol/A]    0.323    0.340
# epoch:  52                    train:   valid:
#     loss [a.u.]                0.103    0.127
#     energy mae [kcal/mol]      0.089    0.134
#     forces mae [kcal/mol/A]    0.323    0.343
# epoch:  53                    train:   valid:
#     loss [a.u.]                0.104    0.119
#     energy mae [kcal/mol]      0.097    0.093
#     forces mae [kcal/mol/A]    0.324    0.338
# Updating best model...
# epoch:  54                    train:   valid:
#     loss [a.u.]                0.102    0.122
#     energy mae [kcal/mol]      0.085    0.104
#     forces mae [kcal/mol/A]    0.323    0.337
# Updating best model...
# epoch:  55                    train:   valid:
#     loss [a.u.]                0.101    0.121
#     energy mae [kcal/mol]      0.084    0.099
#     forces mae [kcal/mol/A]    0.320    0.339
# epoch:  56                    train:   valid:
#     loss [a.u.]                0.101    0.120
#     energy mae [kcal/mol]      0.090    0.096
#     forces mae [kcal/mol/A]    0.320    0.337
# epoch:  57                    train:   valid:
#     loss [a.u.]                0.101    0.119
#     energy mae [kcal/mol]      0.088    0.096
#     forces mae [kcal/mol/A]    0.319    0.336
# Updating best model...
# epoch:  58                    train:   valid:
#     loss [a.u.]                0.104    0.121
#     energy mae [kcal/mol]      0.107    0.112
#     forces mae [kcal/mol/A]    0.321    0.337
# epoch:  59                    train:   valid:
#     loss [a.u.]                0.102    0.121
#     energy mae [kcal/mol]      0.100    0.111
#     forces mae [kcal/mol/A]    0.319    0.335
# Updating best model...
# epoch:  60                    train:   valid:
#     loss [a.u.]                0.102    0.127
#     energy mae [kcal/mol]      0.097    0.117
#     forces mae [kcal/mol/A]    0.320    0.345
# epoch:  61                    train:   valid:
#     loss [a.u.]                0.101    0.119
#     energy mae [kcal/mol]      0.097    0.103
#     forces mae [kcal/mol/A]    0.319    0.334
# Updating best model...
# epoch:  62                    train:   valid:
#     loss [a.u.]                0.098    0.121
#     energy mae [kcal/mol]      0.086    0.098
#     forces mae [kcal/mol/A]    0.315    0.337
# epoch:  63                    train:   valid:
#     loss [a.u.]                0.099    0.116
#     energy mae [kcal/mol]      0.089    0.093
#     forces mae [kcal/mol/A]    0.317    0.331
# Updating best model...
# epoch:  64                    train:   valid:
#     loss [a.u.]                0.097    0.118
#     energy mae [kcal/mol]      0.089    0.118
#     forces mae [kcal/mol/A]    0.313    0.331
# Updating best model...
# epoch:  65                    train:   valid:
#     loss [a.u.]                0.097    0.118
#     energy mae [kcal/mol]      0.087    0.102
#     forces mae [kcal/mol/A]    0.312    0.333
# epoch:  66                    train:   valid:
#     loss [a.u.]                0.098    0.116
#     energy mae [kcal/mol]      0.093    0.093
#     forces mae [kcal/mol/A]    0.315    0.331
# epoch:  67                    train:   valid:
#     loss [a.u.]                0.096    0.114
#     energy mae [kcal/mol]      0.088    0.091
#     forces mae [kcal/mol/A]    0.310    0.328
# Updating best model...
# epoch:  68                    train:   valid:
#     loss [a.u.]                0.095    0.116
#     energy mae [kcal/mol]      0.083    0.097
#     forces mae [kcal/mol/A]    0.310    0.330
# epoch:  69                    train:   valid:
#     loss [a.u.]                0.097    0.120
#     energy mae [kcal/mol]      0.089    0.103
#     forces mae [kcal/mol/A]    0.313    0.339
# epoch:  70                    train:   valid:
#     loss [a.u.]                0.096    0.116
#     energy mae [kcal/mol]      0.088    0.096
#     forces mae [kcal/mol/A]    0.312    0.331
# epoch:  71                    train:   valid:
#     loss [a.u.]                0.095    0.116
#     energy mae [kcal/mol]      0.085    0.100
#     forces mae [kcal/mol/A]    0.310    0.329
# epoch:  72                    train:   valid:
#     loss [a.u.]                0.095    0.116
#     energy mae [kcal/mol]      0.084    0.099
#     forces mae [kcal/mol/A]    0.310    0.329
# epoch:  73                    train:   valid:
#     loss [a.u.]                0.094    0.113
#     energy mae [kcal/mol]      0.088    0.090
#     forces mae [kcal/mol/A]    0.308    0.326
# Updating best model...
# epoch:  74                    train:   valid:
#     loss [a.u.]                0.094    0.115
#     energy mae [kcal/mol]      0.083    0.094
#     forces mae [kcal/mol/A]    0.308    0.328
# epoch:  75                    train:   valid:
#     loss [a.u.]                0.094    0.113
#     energy mae [kcal/mol]      0.086    0.095
#     forces mae [kcal/mol/A]    0.308    0.327
# epoch:  76                    train:   valid:
#     loss [a.u.]                0.094    0.113
#     energy mae [kcal/mol]      0.085    0.100
#     forces mae [kcal/mol/A]    0.309    0.326
# epoch:  77                    train:   valid:
#     loss [a.u.]                0.094    0.114
#     energy mae [kcal/mol]      0.094    0.090
#     forces mae [kcal/mol/A]    0.307    0.330
# epoch:  78                    train:   valid:
#     loss [a.u.]                0.094    0.113
#     energy mae [kcal/mol]      0.086    0.097
#     forces mae [kcal/mol/A]    0.308    0.325
# Updating best model...
# epoch:  79                    train:   valid:
#     loss [a.u.]                0.093    0.113
#     energy mae [kcal/mol]      0.091    0.108
#     forces mae [kcal/mol/A]    0.305    0.325
# epoch:  80                    train:   valid:
#     loss [a.u.]                0.092    0.112
#     energy mae [kcal/mol]      0.087    0.095
#     forces mae [kcal/mol/A]    0.303    0.323
# Updating best model...
# epoch:  81                    train:   valid:
#     loss [a.u.]                0.093    0.115
#     energy mae [kcal/mol]      0.087    0.116
#     forces mae [kcal/mol/A]    0.306    0.328
# epoch:  82                    train:   valid:
#     loss [a.u.]                0.092    0.115
#     energy mae [kcal/mol]      0.084    0.110
#     forces mae [kcal/mol/A]    0.305    0.327
# epoch:  83                    train:   valid:
#     loss [a.u.]                0.093    0.115
#     energy mae [kcal/mol]      0.097    0.113
#     forces mae [kcal/mol/A]    0.304    0.323
# Updating best model...
# epoch:  84                    train:   valid:
#     loss [a.u.]                0.090    0.111
#     energy mae [kcal/mol]      0.079    0.093
#     forces mae [kcal/mol/A]    0.302    0.324
# epoch:  85                    train:   valid:
#     loss [a.u.]                0.091    0.113
#     energy mae [kcal/mol]      0.088    0.107
#     forces mae [kcal/mol/A]    0.303    0.324
# epoch:  86                    train:   valid:
#     loss [a.u.]                0.090    0.111
#     energy mae [kcal/mol]      0.079    0.089
#     forces mae [kcal/mol/A]    0.302    0.323
# epoch:  87                    train:   valid:
#     loss [a.u.]                0.092    0.117
#     energy mae [kcal/mol]      0.092    0.106
#     forces mae [kcal/mol/A]    0.303    0.327
# epoch:  88                    train:   valid:
#     loss [a.u.]                0.092    0.114
#     energy mae [kcal/mol]      0.092    0.122
#     forces mae [kcal/mol/A]    0.302    0.324
# epoch:  89                    train:   valid:
#     loss [a.u.]                0.091    0.115
#     energy mae [kcal/mol]      0.088    0.109
#     forces mae [kcal/mol/A]    0.302    0.329
# epoch:  90                    train:   valid:
#     loss [a.u.]                0.090    0.111
#     energy mae [kcal/mol]      0.086    0.101
#     forces mae [kcal/mol/A]    0.301    0.322
# Updating best model...
# epoch:  91                    train:   valid:
#     loss [a.u.]                0.089    0.110
#     energy mae [kcal/mol]      0.083    0.098
#     forces mae [kcal/mol/A]    0.300    0.323
# epoch:  92                    train:   valid:
#     loss [a.u.]                0.088    0.113
#     energy mae [kcal/mol]      0.083    0.105
#     forces mae [kcal/mol/A]    0.298    0.323
# epoch:  93                    train:   valid:
#     loss [a.u.]                0.092    0.118
#     energy mae [kcal/mol]      0.101    0.131
#     forces mae [kcal/mol/A]    0.303    0.326
# epoch:  94                    train:   valid:
#     loss [a.u.]                0.088    0.109
#     energy mae [kcal/mol]      0.081    0.090
#     forces mae [kcal/mol/A]    0.299    0.317
# Updating best model...
# epoch:  95                    train:   valid:
#     loss [a.u.]                0.087    0.108
#     energy mae [kcal/mol]      0.079    0.090
#     forces mae [kcal/mol/A]    0.297    0.317
# epoch:  96                    train:   valid:
#     loss [a.u.]                0.089    0.110
#     energy mae [kcal/mol]      0.087    0.096
#     forces mae [kcal/mol/A]    0.299    0.319
# epoch:  97                    train:   valid:
#     loss [a.u.]                0.088    0.109
#     energy mae [kcal/mol]      0.083    0.091
#     forces mae [kcal/mol/A]    0.298    0.320
# epoch:  98                    train:   valid:
#     loss [a.u.]                0.089    0.112
#     energy mae [kcal/mol]      0.084    0.102
#     forces mae [kcal/mol/A]    0.300    0.324
# epoch:  99                    train:   valid:
#     loss [a.u.]                0.087    0.111
#     energy mae [kcal/mol]      0.084    0.128
#     forces mae [kcal/mol/A]    0.297    0.317
# epoch:  100                    train:   valid:
#     loss [a.u.]                0.087    0.112
#     energy mae [kcal/mol]      0.082    0.108
#     forces mae [kcal/mol/A]    0.295    0.325
# epoch:  101                    train:   valid:
#     loss [a.u.]                0.087    0.111
#     energy mae [kcal/mol]      0.086    0.108
#     forces mae [kcal/mol/A]    0.296    0.318
# epoch:  102                    train:   valid:
#     loss [a.u.]                0.087    0.108
#     energy mae [kcal/mol]      0.084    0.099
#     forces mae [kcal/mol/A]    0.295    0.321
# epoch:  103                    train:   valid:
#     loss [a.u.]                0.087    0.112
#     energy mae [kcal/mol]      0.083    0.124
#     forces mae [kcal/mol/A]    0.296    0.321
# epoch:  104                    train:   valid:
#     loss [a.u.]                0.086    0.106
#     energy mae [kcal/mol]      0.080    0.085
#     forces mae [kcal/mol/A]    0.294    0.313
# Updating best model...
# epoch:  105                    train:   valid:
#     loss [a.u.]                0.087    0.109
#     energy mae [kcal/mol]      0.085    0.091
#     forces mae [kcal/mol/A]    0.295    0.317
# epoch:  106                    train:   valid:
#     loss [a.u.]                0.085    0.107
#     energy mae [kcal/mol]      0.073    0.092
#     forces mae [kcal/mol/A]    0.294    0.315
# epoch:  107                    train:   valid:
#     loss [a.u.]                0.087    0.110
#     energy mae [kcal/mol]      0.089    0.098
#     forces mae [kcal/mol/A]    0.294    0.318
# epoch:  108                    train:   valid:
#     loss [a.u.]                0.086    0.107
#     energy mae [kcal/mol]      0.081    0.090
#     forces mae [kcal/mol/A]    0.295    0.315
# epoch:  109                    train:   valid:
#     loss [a.u.]                0.085    0.106
#     energy mae [kcal/mol]      0.078    0.090
#     forces mae [kcal/mol/A]    0.293    0.313
# Updating best model...
# epoch:  110                    train:   valid:
#     loss [a.u.]                0.085    0.108
#     energy mae [kcal/mol]      0.078    0.095
#     forces mae [kcal/mol/A]    0.292    0.315
# epoch:  111                    train:   valid:
#     loss [a.u.]                0.085    0.106
#     energy mae [kcal/mol]      0.077    0.090
#     forces mae [kcal/mol/A]    0.293    0.313
# epoch:  112                    train:   valid:
#     loss [a.u.]                0.084    0.109
#     energy mae [kcal/mol]      0.076    0.103
#     forces mae [kcal/mol/A]    0.292    0.318
# epoch:  113                    train:   valid:
#     loss [a.u.]                0.083    0.105
#     energy mae [kcal/mol]      0.077    0.102
#     forces mae [kcal/mol/A]    0.290    0.310
# Updating best model...
# epoch:  114                    train:   valid:
#     loss [a.u.]                0.084    0.107
#     energy mae [kcal/mol]      0.082    0.099
#     forces mae [kcal/mol/A]    0.291    0.315
# epoch:  115                    train:   valid:
#     loss [a.u.]                0.086    0.107
#     energy mae [kcal/mol]      0.089    0.088
#     forces mae [kcal/mol/A]    0.293    0.318
# epoch:  116                    train:   valid:
#     loss [a.u.]                0.083    0.106
#     energy mae [kcal/mol]      0.075    0.112
#     forces mae [kcal/mol/A]    0.289    0.310
# epoch:  117                    train:   valid:
#     loss [a.u.]                0.087    0.106
#     energy mae [kcal/mol]      0.100    0.098
#     forces mae [kcal/mol/A]    0.292    0.315
# epoch:  118                    train:   valid:
#     loss [a.u.]                0.084    0.109
#     energy mae [kcal/mol]      0.089    0.117
#     forces mae [kcal/mol/A]    0.290    0.317
# epoch:  119                    train:   valid:
#     loss [a.u.]                0.082    0.107
#     energy mae [kcal/mol]      0.076    0.107
#     forces mae [kcal/mol/A]    0.288    0.312
# epoch:  120                    train:   valid:
#     loss [a.u.]                0.082    0.104
#     energy mae [kcal/mol]      0.072    0.086
#     forces mae [kcal/mol/A]    0.289    0.311
# epoch:  121                    train:   valid:
#     loss [a.u.]                0.083    0.108
#     energy mae [kcal/mol]      0.077    0.091
#     forces mae [kcal/mol/A]    0.289    0.318
# epoch:  122                    train:   valid:
#     loss [a.u.]                0.082    0.105
#     energy mae [kcal/mol]      0.074    0.088
#     forces mae [kcal/mol/A]    0.289    0.314
# epoch:  123                    train:   valid:
#     loss [a.u.]                0.083    0.105
#     energy mae [kcal/mol]      0.077    0.101
#     forces mae [kcal/mol/A]    0.290    0.311
# epoch:  124                    train:   valid:
#     loss [a.u.]                0.085    0.107
#     energy mae [kcal/mol]      0.086    0.095
#     forces mae [kcal/mol/A]    0.292    0.313
# epoch:  125                    train:   valid:
#     loss [a.u.]                0.083    0.104
#     energy mae [kcal/mol]      0.088    0.095
#     forces mae [kcal/mol/A]    0.286    0.310
# Updating best model...
# epoch:  126                    train:   valid:
#     loss [a.u.]                0.087    0.113
#     energy mae [kcal/mol]      0.104    0.131
#     forces mae [kcal/mol/A]    0.291    0.320
# epoch:  127                    train:   valid:
#     loss [a.u.]                0.083    0.108
#     energy mae [kcal/mol]      0.080    0.103
#     forces mae [kcal/mol/A]    0.288    0.317
# epoch:  128                    train:   valid:
#     loss [a.u.]                0.081    0.105
#     energy mae [kcal/mol]      0.070    0.093
#     forces mae [kcal/mol/A]    0.287    0.312
# epoch:  129                    train:   valid:
#     loss [a.u.]                0.080    0.103
#     energy mae [kcal/mol]      0.070    0.091
#     forces mae [kcal/mol/A]    0.285    0.309
# Updating best model...
# epoch:  130                    train:   valid:
#     loss [a.u.]                0.081    0.104
#     energy mae [kcal/mol]      0.082    0.096
#     forces mae [kcal/mol/A]    0.286    0.309
# Updating best model...
# epoch:  131                    train:   valid:
#     loss [a.u.]                0.082    0.108
#     energy mae [kcal/mol]      0.085    0.112
#     forces mae [kcal/mol/A]    0.286    0.315
# epoch:  132                    train:   valid:
#     loss [a.u.]                0.083    0.103
#     energy mae [kcal/mol]      0.085    0.086
#     forces mae [kcal/mol/A]    0.288    0.309
# Updating best model...
# epoch:  133                    train:   valid:
#     loss [a.u.]                0.080    0.103
#     energy mae [kcal/mol]      0.073    0.090
#     forces mae [kcal/mol/A]    0.284    0.310
# epoch:  134                    train:   valid:
#     loss [a.u.]                0.080    0.105
#     energy mae [kcal/mol]      0.072    0.101
#     forces mae [kcal/mol/A]    0.285    0.312
# epoch:  135                    train:   valid:
#     loss [a.u.]                0.081    0.108
#     energy mae [kcal/mol]      0.079    0.130
#     forces mae [kcal/mol/A]    0.285    0.310
# epoch:  136                    train:   valid:
#     loss [a.u.]                0.079    0.102
#     energy mae [kcal/mol]      0.075    0.088
#     forces mae [kcal/mol/A]    0.283    0.308
# Updating best model...
# epoch:  137                    train:   valid:
#     loss [a.u.]                0.079    0.103
#     energy mae [kcal/mol]      0.073    0.089
#     forces mae [kcal/mol/A]    0.284    0.307
# Updating best model...
# epoch:  138                    train:   valid:
#     loss [a.u.]                0.080    0.108
#     energy mae [kcal/mol]      0.082    0.123
#     forces mae [kcal/mol/A]    0.283    0.311
# epoch:  139                    train:   valid:
#     loss [a.u.]                0.083    0.103
#     energy mae [kcal/mol]      0.098    0.093
#     forces mae [kcal/mol/A]    0.285    0.308
# epoch:  140                    train:   valid:
#     loss [a.u.]                0.081    0.105
#     energy mae [kcal/mol]      0.080    0.102
#     forces mae [kcal/mol/A]    0.285    0.309
# epoch:  141                    train:   valid:
#     loss [a.u.]                0.079    0.103
#     energy mae [kcal/mol]      0.075    0.090
#     forces mae [kcal/mol/A]    0.283    0.308
# epoch:  142                    train:   valid:
#     loss [a.u.]                0.080    0.106
#     energy mae [kcal/mol]      0.073    0.097
#     forces mae [kcal/mol/A]    0.284    0.312
# epoch:  143                    train:   valid:
#     loss [a.u.]                0.079    0.101
#     energy mae [kcal/mol]      0.072    0.087
#     forces mae [kcal/mol/A]    0.284    0.306
# Updating best model...
# epoch:  144                    train:   valid:
#     loss [a.u.]                0.081    0.104
#     energy mae [kcal/mol]      0.086    0.095
#     forces mae [kcal/mol/A]    0.286    0.309
# epoch:  145                    train:   valid:
#     loss [a.u.]                0.079    0.103
#     energy mae [kcal/mol]      0.073    0.100
#     forces mae [kcal/mol/A]    0.283    0.309
# epoch:  146                    train:   valid:
#     loss [a.u.]                0.078    0.102
#     energy mae [kcal/mol]      0.069    0.093
#     forces mae [kcal/mol/A]    0.283    0.305
# Updating best model...
# epoch:  147                    train:   valid:
#     loss [a.u.]                0.079    0.101
#     energy mae [kcal/mol]      0.081    0.088
#     forces mae [kcal/mol/A]    0.281    0.307
# epoch:  148                    train:   valid:
#     loss [a.u.]                0.078    0.104
#     energy mae [kcal/mol]      0.072    0.092
#     forces mae [kcal/mol/A]    0.281    0.310
# epoch:  149                    train:   valid:
#     loss [a.u.]                0.080    0.100
#     energy mae [kcal/mol]      0.081    0.085
#     forces mae [kcal/mol/A]    0.284    0.303
# Updating best model...
# epoch:  150                    train:   valid:
#     loss [a.u.]                0.078    0.105
#     energy mae [kcal/mol]      0.074    0.110
#     forces mae [kcal/mol/A]    0.281    0.309
# epoch:  151                    train:   valid:
#     loss [a.u.]                0.078    0.106
#     energy mae [kcal/mol]      0.075    0.128
#     forces mae [kcal/mol/A]    0.281    0.307
# epoch:  152                    train:   valid:
#     loss [a.u.]                0.078    0.100
#     energy mae [kcal/mol]      0.076    0.092
#     forces mae [kcal/mol/A]    0.281    0.303
# Updating best model...
# epoch:  153                    train:   valid:
#     loss [a.u.]                0.079    0.103
#     energy mae [kcal/mol]      0.083    0.095
#     forces mae [kcal/mol/A]    0.280    0.305
# epoch:  154                    train:   valid:
#     loss [a.u.]                0.078    0.100
#     energy mae [kcal/mol]      0.077    0.093
#     forces mae [kcal/mol/A]    0.279    0.302
# Updating best model...
# epoch:  155                    train:   valid:
#     loss [a.u.]                0.077    0.101
#     energy mae [kcal/mol]      0.071    0.087
#     forces mae [kcal/mol/A]    0.278    0.304
# epoch:  156                    train:   valid:
#     loss [a.u.]                0.083    0.104
#     energy mae [kcal/mol]      0.102    0.106
#     forces mae [kcal/mol/A]    0.284    0.310
# epoch:  157                    train:   valid:
#     loss [a.u.]                0.077    0.100
#     energy mae [kcal/mol]      0.071    0.088
#     forces mae [kcal/mol/A]    0.280    0.301
# Updating best model...
# epoch:  158                    train:   valid:
#     loss [a.u.]                0.076    0.102
#     energy mae [kcal/mol]      0.071    0.108
#     forces mae [kcal/mol/A]    0.278    0.302
# epoch:  159                    train:   valid:
#     loss [a.u.]                0.079    0.099
#     energy mae [kcal/mol]      0.084    0.083
#     forces mae [kcal/mol/A]    0.280    0.303
# epoch:  160                    train:   valid:
#     loss [a.u.]                0.076    0.102
#     energy mae [kcal/mol]      0.070    0.093
#     forces mae [kcal/mol/A]    0.277    0.305
# epoch:  161                    train:   valid:
#     loss [a.u.]                0.077    0.101
#     energy mae [kcal/mol]      0.073    0.094
#     forces mae [kcal/mol/A]    0.278    0.303
# epoch:  162                    train:   valid:
#     loss [a.u.]                0.075    0.101
#     energy mae [kcal/mol]      0.069    0.089
#     forces mae [kcal/mol/A]    0.276    0.303
# epoch:  163                    train:   valid:
#     loss [a.u.]                0.076    0.103
#     energy mae [kcal/mol]      0.070    0.099
#     forces mae [kcal/mol/A]    0.278    0.308
# epoch:  164                    train:   valid:
#     loss [a.u.]                0.076    0.100
#     energy mae [kcal/mol]      0.069    0.089
#     forces mae [kcal/mol/A]    0.278    0.302
# epoch:  165                    train:   valid:
#     loss [a.u.]                0.075    0.100
#     energy mae [kcal/mol]      0.069    0.105
#     forces mae [kcal/mol/A]    0.276    0.299
# Updating best model...
# epoch:  166                    train:   valid:
#     loss [a.u.]                0.075    0.101
#     energy mae [kcal/mol]      0.075    0.103
#     forces mae [kcal/mol/A]    0.275    0.302
# epoch:  167                    train:   valid:
#     loss [a.u.]                0.075    0.103
#     energy mae [kcal/mol]      0.070    0.117
#     forces mae [kcal/mol/A]    0.276    0.304
# epoch:  168                    train:   valid:
#     loss [a.u.]                0.076    0.100
#     energy mae [kcal/mol]      0.077    0.097
#     forces mae [kcal/mol/A]    0.277    0.301
# epoch:  169                    train:   valid:
#     loss [a.u.]                0.076    0.099
#     energy mae [kcal/mol]      0.074    0.089
#     forces mae [kcal/mol/A]    0.278    0.301
# epoch:  170                    train:   valid:
#     loss [a.u.]                0.077    0.106
#     energy mae [kcal/mol]      0.080    0.104
#     forces mae [kcal/mol/A]    0.278    0.309
# epoch:  171                    train:   valid:
#     loss [a.u.]                0.076    0.099
#     energy mae [kcal/mol]      0.072    0.091
#     forces mae [kcal/mol/A]    0.277    0.298
# Updating best model...
# epoch:  172                    train:   valid:
#     loss [a.u.]                0.077    0.101
#     energy mae [kcal/mol]      0.081    0.107
#     forces mae [kcal/mol/A]    0.278    0.301
# epoch:  173                    train:   valid:
#     loss [a.u.]                0.075    0.099
#     energy mae [kcal/mol]      0.071    0.091
#     forces mae [kcal/mol/A]    0.276    0.302
# epoch:  174                    train:   valid:
#     loss [a.u.]                0.076    0.102
#     energy mae [kcal/mol]      0.079    0.114
#     forces mae [kcal/mol/A]    0.277    0.301
# epoch:  175                    train:   valid:
#     loss [a.u.]                0.077    0.101
#     energy mae [kcal/mol]      0.086    0.089
#     forces mae [kcal/mol/A]    0.278    0.306
# epoch:  176                    train:   valid:
#     loss [a.u.]                0.074    0.098
#     energy mae [kcal/mol]      0.071    0.084
#     forces mae [kcal/mol/A]    0.274    0.298
# Updating best model...
# epoch:  177                    train:   valid:
#     loss [a.u.]                0.075    0.100
#     energy mae [kcal/mol]      0.072    0.090
#     forces mae [kcal/mol/A]    0.275    0.302
# epoch:  178                    train:   valid:
#     loss [a.u.]                0.074    0.098
#     energy mae [kcal/mol]      0.067    0.083
#     forces mae [kcal/mol/A]    0.275    0.298
# Updating best model...
# epoch:  179                    train:   valid:
#     loss [a.u.]                0.077    0.100
#     energy mae [kcal/mol]      0.082    0.098
#     forces mae [kcal/mol/A]    0.277    0.303
# epoch:  180                    train:   valid:
#     loss [a.u.]                0.074    0.098
#     energy mae [kcal/mol]      0.072    0.082
#     forces mae [kcal/mol/A]    0.274    0.298
# epoch:  181                    train:   valid:
#     loss [a.u.]                0.074    0.103
#     energy mae [kcal/mol]      0.069    0.114
#     forces mae [kcal/mol/A]    0.273    0.304
# epoch:  182                    train:   valid:
#     loss [a.u.]                0.076    0.099
#     energy mae [kcal/mol]      0.080    0.088
#     forces mae [kcal/mol/A]    0.275    0.299
# epoch:  183                    train:   valid:
#     loss [a.u.]                0.078    0.099
#     energy mae [kcal/mol]      0.091    0.099
#     forces mae [kcal/mol/A]    0.277    0.298
# epoch:  184                    train:   valid:
#     loss [a.u.]                0.074    0.098
#     energy mae [kcal/mol]      0.074    0.085
#     forces mae [kcal/mol/A]    0.273    0.298
# Updating best model...
# epoch:  185                    train:   valid:
#     loss [a.u.]                0.075    0.099
#     energy mae [kcal/mol]      0.076    0.086
#     forces mae [kcal/mol/A]    0.274    0.300
# epoch:  186                    train:   valid:
#     loss [a.u.]                0.074    0.099
#     energy mae [kcal/mol]      0.073    0.092
#     forces mae [kcal/mol/A]    0.272    0.301
# epoch:  187                    train:   valid:
#     loss [a.u.]                0.074    0.099
#     energy mae [kcal/mol]      0.072    0.089
#     forces mae [kcal/mol/A]    0.273    0.298
# epoch:  188                    train:   valid:
#     loss [a.u.]                0.074    0.098
#     energy mae [kcal/mol]      0.076    0.091
#     forces mae [kcal/mol/A]    0.274    0.300
# epoch:  189                    train:   valid:
#     loss [a.u.]                0.075    0.101
#     energy mae [kcal/mol]      0.075    0.117
#     forces mae [kcal/mol/A]    0.275    0.301
# epoch:  190                    train:   valid:
#     loss [a.u.]                0.073    0.100
#     energy mae [kcal/mol]      0.075    0.105
#     forces mae [kcal/mol/A]    0.271    0.297
# Updating best model...
# epoch:  191                    train:   valid:
#     loss [a.u.]                0.073    0.101
#     energy mae [kcal/mol]      0.068    0.104
#     forces mae [kcal/mol/A]    0.271    0.301
# epoch:  192                    train:   valid:
#     loss [a.u.]                0.074    0.097
#     energy mae [kcal/mol]      0.074    0.085
#     forces mae [kcal/mol/A]    0.273    0.298
# epoch:  193                    train:   valid:
#     loss [a.u.]                0.074    0.101
#     energy mae [kcal/mol]      0.074    0.123
#     forces mae [kcal/mol/A]    0.273    0.296
# Updating best model...
# epoch:  194                    train:   valid:
#     loss [a.u.]                0.073    0.098
#     energy mae [kcal/mol]      0.076    0.089
#     forces mae [kcal/mol/A]    0.271    0.298
# epoch:  195                    train:   valid:
#     loss [a.u.]                0.074    0.100
#     energy mae [kcal/mol]      0.081    0.091
#     forces mae [kcal/mol/A]    0.272    0.304
# epoch:  196                    train:   valid:
#     loss [a.u.]                0.072    0.098
#     energy mae [kcal/mol]      0.068    0.085
#     forces mae [kcal/mol/A]    0.270    0.298
# epoch:  197                    train:   valid:
#     loss [a.u.]                0.073    0.099
#     energy mae [kcal/mol]      0.074    0.099
#     forces mae [kcal/mol/A]    0.270    0.297
# epoch:  198                    train:   valid:
#     loss [a.u.]                0.072    0.101
#     energy mae [kcal/mol]      0.069    0.121
#     forces mae [kcal/mol/A]    0.268    0.296
# Updating best model...
# epoch:  199                    train:   valid:
#     loss [a.u.]                0.073    0.097
#     energy mae [kcal/mol]      0.074    0.093
#     forces mae [kcal/mol/A]    0.270    0.296
# epoch:  200                    train:   valid:
#     loss [a.u.]                0.073    0.103
#     energy mae [kcal/mol]      0.079    0.141
#     forces mae [kcal/mol/A]    0.270    0.296
# epoch:  201                    train:   valid:
#     loss [a.u.]                0.073    0.097
#     energy mae [kcal/mol]      0.076    0.092
#     forces mae [kcal/mol/A]    0.271    0.294
# Updating best model...
# epoch:  202                    train:   valid:
#     loss [a.u.]                0.073    0.098
#     energy mae [kcal/mol]      0.077    0.093
#     forces mae [kcal/mol/A]    0.270    0.299
# epoch:  203                    train:   valid:
#     loss [a.u.]                0.073    0.099
#     energy mae [kcal/mol]      0.075    0.087
#     forces mae [kcal/mol/A]    0.272    0.300
# epoch:  204                    train:   valid:
#     loss [a.u.]                0.072    0.097
#     energy mae [kcal/mol]      0.067    0.084
#     forces mae [kcal/mol/A]    0.270    0.298
# epoch:  205                    train:   valid:
#     loss [a.u.]                0.072    0.098
#     energy mae [kcal/mol]      0.072    0.100
#     forces mae [kcal/mol/A]    0.270    0.297
# epoch:  206                    train:   valid:
#     loss [a.u.]                0.072    0.096
#     energy mae [kcal/mol]      0.074    0.091
#     forces mae [kcal/mol/A]    0.269    0.294
# epoch:  207                    train:   valid:
#     loss [a.u.]                0.072    0.099
#     energy mae [kcal/mol]      0.071    0.090
#     forces mae [kcal/mol/A]    0.270    0.300
# epoch:  208                    train:   valid:
#     loss [a.u.]                0.072    0.096
#     energy mae [kcal/mol]      0.069    0.083
#     forces mae [kcal/mol/A]    0.270    0.297
# epoch:  209                    train:   valid:
#     loss [a.u.]                0.072    0.098
#     energy mae [kcal/mol]      0.072    0.103
#     forces mae [kcal/mol/A]    0.269    0.297
# epoch:  210                    train:   valid:
#     loss [a.u.]                0.072    0.101
#     energy mae [kcal/mol]      0.076    0.128
#     forces mae [kcal/mol/A]    0.269    0.297
# epoch:  211                    train:   valid:
#     loss [a.u.]                0.072    0.095
#     energy mae [kcal/mol]      0.081    0.085
#     forces mae [kcal/mol/A]    0.269    0.293
# Updating best model...
# epoch:  212                    train:   valid:
#     loss [a.u.]                0.071    0.095
#     energy mae [kcal/mol]      0.071    0.090
#     forces mae [kcal/mol/A]    0.268    0.293
# epoch:  213                    train:   valid:
#     loss [a.u.]                0.072    0.100
#     energy mae [kcal/mol]      0.077    0.103
#     forces mae [kcal/mol/A]    0.269    0.299
# epoch:  214                    train:   valid:
#     loss [a.u.]                0.074    0.095
#     energy mae [kcal/mol]      0.081    0.085
#     forces mae [kcal/mol/A]    0.272    0.293
# epoch:  215                    train:   valid:
#     loss [a.u.]                0.073    0.100
#     energy mae [kcal/mol]      0.073    0.094
#     forces mae [kcal/mol/A]    0.270    0.299
# epoch:  216                    train:   valid:
#     loss [a.u.]                0.071    0.096
#     energy mae [kcal/mol]      0.070    0.088
#     forces mae [kcal/mol/A]    0.268    0.292
# Updating best model...
# epoch:  217                    train:   valid:
#     loss [a.u.]                0.070    0.096
#     energy mae [kcal/mol]      0.068    0.084
#     forces mae [kcal/mol/A]    0.266    0.296
# epoch:  218                    train:   valid:
#     loss [a.u.]                0.072    0.096
#     energy mae [kcal/mol]      0.074    0.081
#     forces mae [kcal/mol/A]    0.269    0.296
# epoch:  219                    train:   valid:
#     loss [a.u.]                0.072    0.097
#     energy mae [kcal/mol]      0.072    0.088
#     forces mae [kcal/mol/A]    0.270    0.296
# epoch:  220                    train:   valid:
#     loss [a.u.]                0.072    0.095
#     energy mae [kcal/mol]      0.074    0.082
#     forces mae [kcal/mol/A]    0.269    0.292
# Updating best model...
# epoch:  221                    train:   valid:
#     loss [a.u.]                0.071    0.096
#     energy mae [kcal/mol]      0.075    0.096
#     forces mae [kcal/mol/A]    0.268    0.292
# Updating best model...
# epoch:  222                    train:   valid:
#     loss [a.u.]                0.071    0.095
#     energy mae [kcal/mol]      0.069    0.082
#     forces mae [kcal/mol/A]    0.267    0.292
# Updating best model...
# epoch:  223                    train:   valid:
#     loss [a.u.]                0.071    0.096
#     energy mae [kcal/mol]      0.071    0.087
#     forces mae [kcal/mol/A]    0.267    0.294
# epoch:  224                    train:   valid:
#     loss [a.u.]                0.071    0.098
#     energy mae [kcal/mol]      0.070    0.100
#     forces mae [kcal/mol/A]    0.267    0.295
# epoch:  225                    train:   valid:
#     loss [a.u.]                0.070    0.096
#     energy mae [kcal/mol]      0.071    0.092
#     forces mae [kcal/mol/A]    0.266    0.294
# epoch:  226                    train:   valid:
#     loss [a.u.]                0.070    0.100
#     energy mae [kcal/mol]      0.067    0.094
#     forces mae [kcal/mol/A]    0.266    0.302
# epoch:  227                    train:   valid:
#     loss [a.u.]                0.071    0.096
#     energy mae [kcal/mol]      0.070    0.086
#     forces mae [kcal/mol/A]    0.267    0.293
# epoch:  228                    train:   valid:
#     loss [a.u.]                0.070    0.095
#     energy mae [kcal/mol]      0.079    0.085
#     forces mae [kcal/mol/A]    0.264    0.293
# epoch:  229                    train:   valid:
#     loss [a.u.]                0.069    0.097
#     energy mae [kcal/mol]      0.066    0.107
#     forces mae [kcal/mol/A]    0.264    0.291
# Updating best model...
# epoch:  230                    train:   valid:
#     loss [a.u.]                0.070    0.095
#     energy mae [kcal/mol]      0.071    0.082
#     forces mae [kcal/mol/A]    0.265    0.293
# epoch:  231                    train:   valid:
#     loss [a.u.]                0.070    0.097
#     energy mae [kcal/mol]      0.067    0.099
#     forces mae [kcal/mol/A]    0.265    0.294
# epoch:  232                    train:   valid:
#     loss [a.u.]                0.070    0.099
#     energy mae [kcal/mol]      0.071    0.127
#     forces mae [kcal/mol/A]    0.266    0.293
# epoch:  233                    train:   valid:
#     loss [a.u.]                0.070    0.094
#     energy mae [kcal/mol]      0.075    0.085
#     forces mae [kcal/mol/A]    0.265    0.290
# Updating best model...
# epoch:  234                    train:   valid:
#     loss [a.u.]                0.069    0.099
#     energy mae [kcal/mol]      0.066    0.119
#     forces mae [kcal/mol/A]    0.266    0.293
# epoch:  235                    train:   valid:
#     loss [a.u.]                0.069    0.095
#     energy mae [kcal/mol]      0.073    0.083
#     forces mae [kcal/mol/A]    0.263    0.292
# epoch:  236                    train:   valid:
#     loss [a.u.]                0.069    0.096
#     energy mae [kcal/mol]      0.064    0.084
#     forces mae [kcal/mol/A]    0.264    0.295
# epoch:  237                    train:   valid:
#     loss [a.u.]                0.068    0.094
#     energy mae [kcal/mol]      0.065    0.081
#     forces mae [kcal/mol/A]    0.263    0.289
# Updating best model...
# epoch:  238                    train:   valid:
#     loss [a.u.]                0.069    0.097
#     energy mae [kcal/mol]      0.072    0.100
#     forces mae [kcal/mol/A]    0.263    0.296
# epoch:  239                    train:   valid:
#     loss [a.u.]                0.069    0.096
#     energy mae [kcal/mol]      0.063    0.095
#     forces mae [kcal/mol/A]    0.264    0.295
# epoch:  240                    train:   valid:
#     loss [a.u.]                0.070    0.098
#     energy mae [kcal/mol]      0.075    0.105
#     forces mae [kcal/mol/A]    0.264    0.296
# epoch:  241                    train:   valid:
#     loss [a.u.]                0.069    0.094
#     energy mae [kcal/mol]      0.066    0.084
#     forces mae [kcal/mol/A]    0.265    0.290
# epoch:  242                    train:   valid:
#     loss [a.u.]                0.068    0.095
#     energy mae [kcal/mol]      0.065    0.083
#     forces mae [kcal/mol/A]    0.264    0.291
# epoch:  243                    train:   valid:
#     loss [a.u.]                0.069    0.097
#     energy mae [kcal/mol]      0.065    0.093
#     forces mae [kcal/mol/A]    0.264    0.291
# epoch:  244                    train:   valid:
#     loss [a.u.]                0.068    0.094
#     energy mae [kcal/mol]      0.063    0.089
#     forces mae [kcal/mol/A]    0.262    0.291
# epoch:  245                    train:   valid:
#     loss [a.u.]                0.069    0.095
#     energy mae [kcal/mol]      0.073    0.082
#     forces mae [kcal/mol/A]    0.263    0.293
# epoch:  246                    train:   valid:
#     loss [a.u.]                0.070    0.100
#     energy mae [kcal/mol]      0.076    0.098
#     forces mae [kcal/mol/A]    0.266    0.302
# epoch:  247                    train:   valid:
#     loss [a.u.]                0.071    0.098
#     energy mae [kcal/mol]      0.077    0.122
#     forces mae [kcal/mol/A]    0.268    0.293
# epoch:  248                    train:   valid:
#     loss [a.u.]                0.069    0.094
#     energy mae [kcal/mol]      0.075    0.083
#     forces mae [kcal/mol/A]    0.263    0.290
# epoch:  249                    train:   valid:
# ...
#     energy mae [kcal/mol]      0.057    0.084
#     forces mae [kcal/mol/A]    0.240    0.273
# epoch:  532                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.055    0.079
#     forces mae [kcal/mol/A]    0.239    0.273
# epoch:  533                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.061    0.091
#     forces mae [kcal/mol/A]    0.241    0.269
# epoch:  534                    train:   valid:
#     loss [a.u.]                0.056    0.088
#     energy mae [kcal/mol]      0.059    0.104
#     forces mae [kcal/mol/A]    0.239    0.271
# epoch:  535                    train:   valid:
#     loss [a.u.]                0.058    0.085
#     energy mae [kcal/mol]      0.066    0.080
#     forces mae [kcal/mol/A]    0.242    0.273
# epoch:  536                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.063    0.093
#     forces mae [kcal/mol/A]    0.241    0.269
# epoch:  537                    train:   valid:
#     loss [a.u.]                0.057    0.086
#     energy mae [kcal/mol]      0.062    0.088
#     forces mae [kcal/mol/A]    0.240    0.274
# epoch:  538                    train:   valid:
#     loss [a.u.]                0.058    0.086
#     energy mae [kcal/mol]      0.073    0.082
#     forces mae [kcal/mol/A]    0.241    0.274
# epoch:  539                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.061    0.079
#     forces mae [kcal/mol/A]    0.239    0.272
# epoch:  540                    train:   valid:
#     loss [a.u.]                0.057    0.084
#     energy mae [kcal/mol]      0.064    0.077
#     forces mae [kcal/mol/A]    0.239    0.271
# epoch:  541                    train:   valid:
#     loss [a.u.]                0.058    0.087
#     energy mae [kcal/mol]      0.069    0.102
#     forces mae [kcal/mol/A]    0.241    0.272
# epoch:  542                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.062    0.086
#     forces mae [kcal/mol/A]    0.240    0.272
# epoch:  543                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.064    0.089
#     forces mae [kcal/mol/A]    0.238    0.271
# epoch:  544                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.060    0.085
#     forces mae [kcal/mol/A]    0.239    0.274
# epoch:  545                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.062    0.093
#     forces mae [kcal/mol/A]    0.240    0.272
# epoch:  546                    train:   valid:
#     loss [a.u.]                0.058    0.087
#     energy mae [kcal/mol]      0.071    0.096
#     forces mae [kcal/mol/A]    0.241    0.272
# epoch:  547                    train:   valid:
#     loss [a.u.]                0.059    0.088
#     energy mae [kcal/mol]      0.077    0.091
#     forces mae [kcal/mol/A]    0.243    0.278
# epoch:  548                    train:   valid:
#     loss [a.u.]                0.057    0.087
#     energy mae [kcal/mol]      0.066    0.085
#     forces mae [kcal/mol/A]    0.242    0.277
# epoch:  549                    train:   valid:
#     loss [a.u.]                0.057    0.087
#     energy mae [kcal/mol]      0.059    0.095
#     forces mae [kcal/mol/A]    0.241    0.274
# epoch:  550                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.059    0.082
#     forces mae [kcal/mol/A]    0.237    0.274
# epoch:  551                    train:   valid:
#     loss [a.u.]                0.057    0.089
#     energy mae [kcal/mol]      0.068    0.090
#     forces mae [kcal/mol/A]    0.240    0.278
# epoch:  552                    train:   valid:
#     loss [a.u.]                0.058    0.084
#     energy mae [kcal/mol]      0.071    0.079
#     forces mae [kcal/mol/A]    0.242    0.271
# epoch:  553                    train:   valid:
#     loss [a.u.]                0.056    0.083
#     energy mae [kcal/mol]      0.062    0.080
#     forces mae [kcal/mol/A]    0.240    0.268
# Updating best model...
# epoch:  554                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.059    0.083
#     forces mae [kcal/mol/A]    0.239    0.271
# epoch:  555                    train:   valid:
#     loss [a.u.]                0.057    0.088
#     energy mae [kcal/mol]      0.063    0.103
#     forces mae [kcal/mol/A]    0.240    0.279
# epoch:  556                    train:   valid:
#     loss [a.u.]                0.059    0.085
#     energy mae [kcal/mol]      0.078    0.091
#     forces mae [kcal/mol/A]    0.243    0.272
# epoch:  557                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.064    0.091
#     forces mae [kcal/mol/A]    0.240    0.269
# epoch:  558                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.061    0.083
#     forces mae [kcal/mol/A]    0.238    0.271
# epoch:  559                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.061    0.087
#     forces mae [kcal/mol/A]    0.241    0.274
# epoch:  560                    train:   valid:
#     loss [a.u.]                0.056    0.083
#     energy mae [kcal/mol]      0.060    0.074
#     forces mae [kcal/mol/A]    0.239    0.269
# epoch:  561                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.061    0.104
#     forces mae [kcal/mol/A]    0.239    0.273
# epoch:  562                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.061    0.085
#     forces mae [kcal/mol/A]    0.239    0.272
# epoch:  563                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.059    0.080
#     forces mae [kcal/mol/A]    0.238    0.273
# epoch:  564                    train:   valid:
#     loss [a.u.]                0.057    0.086
#     energy mae [kcal/mol]      0.072    0.087
#     forces mae [kcal/mol/A]    0.237    0.274
# epoch:  565                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.061    0.084
#     forces mae [kcal/mol/A]    0.239    0.269
# epoch:  566                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.058    0.085
#     forces mae [kcal/mol/A]    0.237    0.271
# epoch:  567                    train:   valid:
#     loss [a.u.]                0.055    0.086
#     energy mae [kcal/mol]      0.059    0.091
#     forces mae [kcal/mol/A]    0.237    0.276
# epoch:  568                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.066    0.075
#     forces mae [kcal/mol/A]    0.238    0.269
# epoch:  569                    train:   valid:
#     loss [a.u.]                0.055    0.085
#     energy mae [kcal/mol]      0.057    0.081
#     forces mae [kcal/mol/A]    0.238    0.275
# epoch:  570                    train:   valid:
#     loss [a.u.]                0.057    0.084
#     energy mae [kcal/mol]      0.060    0.077
#     forces mae [kcal/mol/A]    0.241    0.272
# epoch:  571                    train:   valid:
#     loss [a.u.]                0.057    0.085
#     energy mae [kcal/mol]      0.071    0.081
#     forces mae [kcal/mol/A]    0.239    0.271
# epoch:  572                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.064    0.078
#     forces mae [kcal/mol/A]    0.238    0.270
# epoch:  573                    train:   valid:
#     loss [a.u.]                0.056    0.083
#     energy mae [kcal/mol]      0.063    0.083
#     forces mae [kcal/mol/A]    0.239    0.268
# epoch:  574                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.064    0.087
#     forces mae [kcal/mol/A]    0.239    0.274
# epoch:  575                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.063    0.080
#     forces mae [kcal/mol/A]    0.238    0.272
# epoch:  576                    train:   valid:
#     loss [a.u.]                0.055    0.084
#     energy mae [kcal/mol]      0.060    0.076
#     forces mae [kcal/mol/A]    0.237    0.270
# epoch:  577                    train:   valid:
#     loss [a.u.]                0.055    0.083
#     energy mae [kcal/mol]      0.058    0.079
#     forces mae [kcal/mol/A]    0.237    0.267
# Updating best model...
# epoch:  578                    train:   valid:
#     loss [a.u.]                0.058    0.087
#     energy mae [kcal/mol]      0.073    0.093
#     forces mae [kcal/mol/A]    0.240    0.274
# epoch:  579                    train:   valid:
#     loss [a.u.]                0.056    0.087
#     energy mae [kcal/mol]      0.062    0.090
#     forces mae [kcal/mol/A]    0.239    0.272
# epoch:  580                    train:   valid:
#     loss [a.u.]                0.056    0.083
#     energy mae [kcal/mol]      0.060    0.075
#     forces mae [kcal/mol/A]    0.239    0.268
# epoch:  581                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.068    0.089
#     forces mae [kcal/mol/A]    0.236    0.269
# epoch:  582                    train:   valid:
#     loss [a.u.]                0.055    0.086
#     energy mae [kcal/mol]      0.062    0.089
#     forces mae [kcal/mol/A]    0.237    0.274
# epoch:  583                    train:   valid:
#     loss [a.u.]                0.057    0.084
#     energy mae [kcal/mol]      0.068    0.077
#     forces mae [kcal/mol/A]    0.240    0.272
# epoch:  584                    train:   valid:
#     loss [a.u.]                0.056    0.083
#     energy mae [kcal/mol]      0.064    0.080
#     forces mae [kcal/mol/A]    0.238    0.267
# Updating best model...
# epoch:  585                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.059    0.083
#     forces mae [kcal/mol/A]    0.238    0.273
# epoch:  586                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.057    0.085
#     forces mae [kcal/mol/A]    0.239    0.272
# epoch:  587                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.063    0.082
#     forces mae [kcal/mol/A]    0.238    0.270
# epoch:  588                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.063    0.082
#     forces mae [kcal/mol/A]    0.237    0.270
# epoch:  589                    train:   valid:
#     loss [a.u.]                0.055    0.083
#     energy mae [kcal/mol]      0.054    0.079
#     forces mae [kcal/mol/A]    0.237    0.270
# epoch:  590                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.065    0.087
#     forces mae [kcal/mol/A]    0.236    0.272
# epoch:  591                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.065    0.080
#     forces mae [kcal/mol/A]    0.239    0.269
# epoch:  592                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.063    0.094
#     forces mae [kcal/mol/A]    0.237    0.270
# epoch:  593                    train:   valid:
#     loss [a.u.]                0.056    0.086
#     energy mae [kcal/mol]      0.061    0.104
#     forces mae [kcal/mol/A]    0.238    0.272
# epoch:  594                    train:   valid:
#     loss [a.u.]                0.057    0.088
#     energy mae [kcal/mol]      0.070    0.111
#     forces mae [kcal/mol/A]    0.239    0.274
# epoch:  595                    train:   valid:
#     loss [a.u.]                0.058    0.085
#     energy mae [kcal/mol]      0.077    0.090
#     forces mae [kcal/mol/A]    0.240    0.274
# epoch:  596                    train:   valid:
#     loss [a.u.]                0.055    0.084
#     energy mae [kcal/mol]      0.055    0.082
#     forces mae [kcal/mol/A]    0.237    0.271
# epoch:  597                    train:   valid:
#     loss [a.u.]                0.054    0.083
#     energy mae [kcal/mol]      0.051    0.083
#     forces mae [kcal/mol/A]    0.234    0.268
# epoch:  598                    train:   valid:
#     loss [a.u.]                0.055    0.084
#     energy mae [kcal/mol]      0.056    0.078
#     forces mae [kcal/mol/A]    0.236    0.271
# epoch:  599                    train:   valid:
#     loss [a.u.]                0.056    0.087
#     energy mae [kcal/mol]      0.063    0.093
#     forces mae [kcal/mol/A]    0.238    0.275
# epoch:  600                    train:   valid:
#     loss [a.u.]                0.055    0.085
#     energy mae [kcal/mol]      0.059    0.077
#     forces mae [kcal/mol/A]    0.238    0.273
# epoch:  601                    train:   valid:
#     loss [a.u.]                0.056    0.084
#     energy mae [kcal/mol]      0.066    0.078
#     forces mae [kcal/mol/A]    0.237    0.273
# epoch:  602                    train:   valid:
#     loss [a.u.]                0.055    0.087
#     energy mae [kcal/mol]      0.057    0.087
#     forces mae [kcal/mol/A]    0.237    0.274
# epoch:  603                    train:   valid:
#     loss [a.u.]                0.058    0.083
#     energy mae [kcal/mol]      0.082    0.079
#     forces mae [kcal/mol/A]    0.239    0.268
# epoch:  604                    train:   valid:
#     loss [a.u.]                0.056    0.085
#     energy mae [kcal/mol]      0.067    0.085
#     forces mae [kcal/mol/A]    0.237    0.275
# epoch:  605                    train:   valid:
#     loss [a.u.]                0.055    0.084
#     energy mae [kcal/mol]      0.066    0.076
#     forces mae [kcal/mol/A]    0.236    0.271
# epoch:  606                    train:   valid:
#     loss [a.u.]                0.057    0.086
#     energy mae [kcal/mol]      0.072    0.102
#     forces mae [kcal/mol/A]    0.238    0.272
# epoch:  607                    train:   valid:
#     loss [a.u.]                0.056    0.092
#     energy mae [kcal/mol]      0.066    0.147
#     forces mae [kcal/mol/A]    0.237    0.273
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 424
#     421 print("Creating MP model [DONE]")
#     423 print("Start training model...")
# --> 424 params = train_model(
#     425     key=train_key,
#     426     model=message_passing_model,
#     427     train_data=train_data,
#     428     valid_data=valid_data,
#     429     num_epochs=num_epochs,
#     430     learning_rate=learning_rate,
#     431     forces_weight=forces_weight,
#     432     batch_size=batch_size,
#     433 )
#     434 print("Start training model [DONE]")
#     435 # print(params)
#
# Cell In[4], line 345, in train_model(key, model, train_data, valid_data, num_epochs, learning_rate, forces_weight, batch_size)
#     336 for i, batch in enumerate(valid_batches):
#     337     loss, energy_mae, forces_mae = eval_step(
#     338         model_apply=model.apply,
#     339         batch=batch,
#    (...)
#     342         params=params,
#     343     )
# --> 345     valid_loss += (loss - valid_loss) / (i + 1)
#     346     valid_energy_mae += (energy_mae - valid_energy_mae) / (i + 1)
#     347     valid_forces_mae += (forces_mae - valid_forces_mae) / (i + 1)
#
# File ~/Documents/e3x/paper/lib/python3.11/site-packages/jax/_src/numpy/array_methods.py:264, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     262 args = (other, self) if swap else (self, other)
#     263 if isinstance(other, _accepted_binop_types):
# --> 264   return binary_op(*args)
#     265 # Note: don't use isinstance here, because we don't want to raise for
#     266 # subclasses, e.g. NamedTuple objects that may override operators.
#     267 if type(other) in _rejected_binop_types:
#
# KeyboardInterrupt:

# %%
# -----------------------------------------------------
# Store best model
params = device_put(params)
jnp.savez(f"best_model{tail_str}.npz", **params)

import io
import pickle

import ase
import ase.calculators.calculator as ase_calc
import ase.io as ase_io
import ase.optimize as ase_opt
import matplotlib.pyplot as plt

# import py3Dmol
import numpy as np
from ase.md.velocitydistribution import (
    MaxwellBoltzmannDistribution,
    Stationary,
    ZeroRotation,
)
from ase.md.verlet import VelocityVerlet

np_load_old = np.load
model = np.load(
    "/home/beemoqc2/Documents/e3x/docs/source/examples/best_model_f32_l1_i5_b16_lion_400k.npz",
    allow_pickle=True,
)
pesos_modelo = {}
for key in model.keys():
    array = model[key]
    pesos_modelo[key] = array

a = model["model"]
a = a.item()
params = a


with open("model_params_train.pkl", "wb") as file:
    pickle.dump(a, file)

with open(
    "/home/beemoqc2/Documents/e3x/docs/source/examples/model_params_train.pkl",
    "rb",
) as file:
    params = pickle.load(file)


@jax.jit
def evaluate_energies_and_forces(atomic_numbers, positions, dst_idx, src_idx):
    return message_passing_model.apply(
        params,
        atomic_numbers=atomic_numbers,
        positions=positions,
        dst_idx=dst_idx,
        src_idx=src_idx,
    )


class MessagePassingCalculator(ase_calc.Calculator):
    implemented_properties = ["energy", "forces"]

    def calculate(
        self, atoms, properties, system_changes=ase.calculators.calculator.all_changes
    ):
        ase_calc.Calculator.calculate(self, atoms, properties, system_changes)
        dst_idx, src_idx = e3x.ops.sparse_pairwise_indices(len(atoms))
        energy, forces = evaluate_energies_and_forces(
            atomic_numbers=atoms.get_atomic_numbers(),
            # positions=atoms.get_positions() / 0.52917721,
            positions=atoms.get_positions(),
            dst_idx=dst_idx,
            src_idx=src_idx,
        )
        self.results["energy"] = energy * ase.units.kcal / ase.units.mol
        self.results["forces"] = forces * ase.units.kcal / ase.units.mol
        # 1 Ha_aims =  27.211384500 eV_aims
        # self.results['energy'] = energy * 27.211384500/1000.0 # 1mHa -> eV
        # self.results['forces'] = forces * 27.211384500/1000.0 / 0.52917721 # 1 mHa/a0 -> eV/Ang


# Initialize atoms object and attach calculator.
print(f"train_data['atomic_numbers'] {train_data['atomic_numbers']}")
atoms = ase.Atoms(train_data["atomic_numbers"], train_data["positions"][0])

print(f"X[0]: {atoms.get_positions()}")
print(f"z: {atoms.get_chemical_symbols()}")

atoms.set_calculator(MessagePassingCalculator())

# Run structure optimization with BFGS.
# ase_opt.BFGS(atoms).run(fmax=1e-3)

# Write structure to xyz file.
# xyz = io.StringIO()
# ase_io.write(xyz, atoms, format='xyz')

# do a quick geometry relaxation
# from ase.optimize import QuasiNewton
from ase.optimize import BFGS
from ase.vibrations import Vibrations

# qn = QuasiNewton(atoms)
# qn.run(1e-3, 100)

BFGS(atoms).run(fmax=0.05)
from ase.io import write

write(f"atoms_{tail_str}.xyz", atoms)

# run the vibration calculations
vib = Vibrations(atoms)
vib.iterdisplace(inplace=True)
vib.run()

# vib.summary() # print a summary of the vibrational frequencies
# vib.write_jmol() # write file for viewing of the modes with jmol
